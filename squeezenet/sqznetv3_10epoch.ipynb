# %% [markdown]
# Colon adenocarcinoma
#
# Colon benign tissue

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# importing libraries

import tensorflow as tf
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img
from tensorflow.keras.models import Sequential
import numpy as np
from glob import glob
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import f1_score, roc_auc_score, cohen_kappa_score, precision_score, recall_score, accuracy_score, confusion_matrix
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, Input
from keras.models import Sequential
import tensorflow as tf
import matplotlib.pyplot as plt
import cv2
#from keras.layers.normalization import BatchNormalization
from keras.models import Model, Sequential
from keras.applications.xception import Xception
from keras.applications import *
import matplotlib.pyplot as plt
from sklearn.pipeline import make_pipeline
from sklearn.pipeline import Pipeline
from PIL import Image
import random
import os
import cv2
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from xgboost import XGBClassifier
from keras.callbacks import EarlyStopping
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from tqdm import tqdm
from sklearn.decomposition import PCA

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
image_set= '/content/drive/MyDrive/PhDProject/colon_image_sets'

# %%
for i,d in enumerate([image_set]):
    filepaths=[]
    labels=[]
    classlist=os.listdir(d)
    for klass in classlist:
        classpath=os.path.join(d,klass)
        if os.path.isdir(classpath):
            flist=os.listdir(classpath)
            for f in flist:
                fpath=os.path.join(classpath,f)
                filepaths.append(fpath)
                labels.append(klass)
    Fseries= pd.Series(filepaths, name='filepaths')
    Lseries=pd.Series(labels, name='labels')
    lung_df=pd.concat([Fseries, Lseries], axis=1)
df=pd.concat([lung_df], axis =0).reset_index(drop=True)# make a combined dataframe

print(df['labels'].value_counts())
# Out:
# colon_normal            5000
# colon_adenocarcinoma    5000
# Name: labels, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
train_split=.7
test_split=.15
dummy_split=test_split/(1-train_split)
train_df, dummy_df=train_test_split(df, train_size=train_split, shuffle=True, random_state=123)
test_df, valid_df=train_test_split(dummy_df, train_size=dummy_split, shuffle=True, random_state=123)
print ('train_df length: ', len(train_df), ' _test_df length: ', len(test_df), '  valid_df length: ', len(valid_df))
# Out:
# train_df length:  7000  _test_df length:  1499   valid_df length:  1501

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
height=224
width=224
channels=3
batch_size=32
img_shape=(height, width, channels)
img_size=(height, width)
length=len(test_df)
test_batch_size=sorted([int(length/n) for n in range(1,length+1) if length % n ==0 and length/n<=80],reverse=True)[0]
test_steps=int(length/test_batch_size)
print ( 'test batch size: ' ,test_batch_size, '  test steps: ', test_steps)
def scalar(img):
    return img/127.5-1  # scale pixel between -1 and +1
gen=ImageDataGenerator(preprocessing_function=scalar)
train_set=gen.flow_from_dataframe( train_df, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical',
                                    color_mode='rgb', shuffle=True, batch_size=batch_size)
test_set=gen.flow_from_dataframe( test_df, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical',
                                    color_mode='rgb', shuffle=False, batch_size=test_batch_size)
validate_set=gen.flow_from_dataframe( valid_df, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical',
                                    color_mode='rgb', shuffle=True, batch_size=batch_size)
#classes=list(train_gen.class_indices.keys())
#class_count=len(classes)
# Out:
# test batch size:  1   test steps:  1499
# Found 7000 validated image filenames belonging to 2 classes.
# Found 1499 validated image filenames belonging to 2 classes.
# Found 1501 validated image filenames belonging to 2 classes.

# %%
IMAGE_SIZE = [224, 224]

# %%
# importing libraries

import tensorflow as tf
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img
from tensorflow.keras.models import Sequential
import numpy as np
from glob import glob
import matplotlib.pyplot as plt

# %%
import os, sys, math
import numpy as np
from matplotlib import pyplot as plt
import tensorflow as tf
print("Tensorflow version " + tf.__version__)
AUTOTUNE = tf.data.AUTOTUNE
# Out:
# Tensorflow version 2.12.0

# %% [markdown]
# tpu detection

# %%
# Increasing the image size didn't result in increasing the training accuracy
IMAGE_WIDTH = 224
IMAGE_HEIGHT = 224
IMAGE_SIZE = (IMAGE_WIDTH, IMAGE_HEIGHT)
IMAGE_CHANNELS = 3

# %%
from tensorflow.keras.layers import (
    Dense,
    Flatten,
    BatchNormalization,
    Conv2D,
    MaxPooling2D,
    GlobalAveragePooling2D,
    Dropout,
    Input,
    Activation,
    concatenate,
)

# %%
bnmomemtum = 0.9


# def fire_module(x, squeeze, expand):
#     y = Conv2D(filters=squeeze, kernel_size=1,  padding="same")(x)
#     y = BatchNormalization(momentum=bnmomemtum)(y)
#     y1 = Conv2D(filters=expand // 2, kernel_size=1,  padding="same")(y)
#     y1 = BatchNormalization(momentum=bnmomemtum)(y1)
#     y3 = Conv2D(filters=expand // 2, kernel_size=3,  padding="same")(y)
#     y3 = BatchNormalization(momentum=bnmomemtum)(y3)
#     return concatenate([y1, y3])


def fire_module(x, squeeze, expand):
    y = Conv2D(filters=squeeze, kernel_size=1,  padding="same")(x)
   # y = BatchNormalization(momentum=bnmomemtum)(y)
    y1 = Conv2D(filters=expand // 2, kernel_size=1,  padding="same")(y)
    # y1 = BatchNormalization(momentum=bnmomemtum)(y1)
    y3 = Conv2D(filters=expand // 2, kernel_size=3,  padding="same")(y)
    # y3 = BatchNormalization(momentum=bnmomemtum)(y3)
    return concatenate([y, y3])


def SqueezeNet(input_shape, num_classes):
    input = Input(shape=input_shape)
    y = Conv2D(kernel_size=7, filters=96, strides=2, padding="same", activation="relu")(input)
   # y = BatchNormalization(momentum=bnmomemtum)(y)
    y = MaxPooling2D(pool_size=3, strides=2)(y)
    y = fire_module(y, 16, 64)
    y = fire_module(y, 16, 64)
    y = fire_module(y, 32, 128)
    y = MaxPooling2D(pool_size=3, strides=2)(y)
    y = fire_module(y, 32, 128)
    y = fire_module(y, 48, 192)
    y = fire_module(y, 48, 192)
    y = fire_module(y, 64, 256)
    y = MaxPooling2D(pool_size=2)(y)
    y = fire_module(y, 64, 256)
    y = Conv2D(kernel_size=1, filters=1000, strides=1, padding="same", activation="relu")(y)
    y = GlobalAveragePooling2D()(y)
    y = Dense(num_classes, activation="softmax")(y)
    model = Model(input, y)
    return model

# %%
categories = {'benign', 'adenocarcinoma'}

# %%
model = SqueezeNet(
    input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, IMAGE_CHANNELS), num_classes=len(categories)
)
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 112, 112, 96  14208       ['input_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 55, 55, 96)   0           ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 55, 55, 16)   1552        ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 55, 55, 32)   4640        ['conv2d_1[0][0]']
#
#  concatenate (Concatenate)      (None, 55, 55, 48)   0           ['conv2d_1[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 55, 55, 16)   784         ['concatenate[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 55, 55, 32)   4640        ['conv2d_4[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 55, 55, 48)   0           ['conv2d_4[0][0]',
#                                                                   'conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 55, 55, 32)   1568        ['concatenate_1[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 55, 55, 64)   18496       ['conv2d_7[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 55, 55, 96)   0           ['conv2d_7[0][0]',
#                                                                   'conv2d_9[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 27, 27, 96)  0           ['concatenate_2[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 27, 27, 32)   3104        ['max_pooling2d_1[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 27, 27, 64)   18496       ['conv2d_10[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 27, 27, 96)   0           ['conv2d_10[0][0]',
#                                                                   'conv2d_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 27, 27, 48)   4656        ['concatenate_3[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 27, 27, 96)   41568       ['conv2d_13[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 27, 27, 144)  0           ['conv2d_13[0][0]',
#                                                                   'conv2d_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 27, 27, 48)   6960        ['concatenate_4[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 27, 27, 96)   41568       ['conv2d_16[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 27, 27, 144)  0           ['conv2d_16[0][0]',
#                                                                   'conv2d_18[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 27, 27, 64)   9280        ['concatenate_5[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 27, 27, 128)  73856       ['conv2d_19[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 27, 27, 192)  0           ['conv2d_19[0][0]',
#                                                                   'conv2d_21[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 13, 13, 192)  0          ['concatenate_6[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 13, 13, 64)   12352       ['max_pooling2d_2[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 13, 13, 128)  73856       ['conv2d_22[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 13, 13, 192)  0           ['conv2d_22[0][0]',
#                                                                   'conv2d_24[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 13, 13, 1000  193000      ['concatenate_7[0][0]']
#                                 )
#
#  global_average_pooling2d (Glob  (None, 1000)        0           ['conv2d_25[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 2)            2002        ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 526,586
# Trainable params: 526,586
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# COMPILING THE MODEL

model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

# %%
#executing the model

history = model.fit(train_set, validation_data = (validate_set), epochs = 50, verbose = 1)
# Out:
# Epoch 1/50
# 219/219 [==============================] - 930s 4s/step - loss: 0.6205 - accuracy: 0.6756 - val_loss: 0.2479 - val_accuracy: 0.8921
# Epoch 2/50
# 219/219 [==============================] - 44s 199ms/step - loss: 0.2742 - accuracy: 0.8823 - val_loss: 0.1489 - val_accuracy: 0.9520
# Epoch 3/50
# 219/219 [==============================] - 44s 200ms/step - loss: 0.2159 - accuracy: 0.9201 - val_loss: 0.0963 - val_accuracy: 0.9740
# Epoch 4/50
# 219/219 [==============================] - 45s 206ms/step - loss: 0.1079 - accuracy: 0.9607 - val_loss: 0.0554 - val_accuracy: 0.9787
# Epoch 5/50
# 219/219 [==============================] - 45s 206ms/step - loss: 0.0821 - accuracy: 0.9703 - val_loss: 0.0439 - val_accuracy: 0.9847
# Epoch 6/50
# 219/219 [==============================] - 45s 207ms/step - loss: 0.0719 - accuracy: 0.9740 - val_loss: 0.0547 - val_accuracy: 0.9833
# Epoch 7/50
# 219/219 [==============================] - 44s 201ms/step - loss: 0.0879 - accuracy: 0.9674 - val_loss: 0.0424 - val_accuracy: 0.9847
# Epoch 8/50
# 219/219 [==============================] - 44s 203ms/step - loss: 0.0546 - accuracy: 0.9813 - val_loss: 0.0378 - val_accuracy: 0.9880
# Epoch 9/50
# 219/219 [==============================] - 43s 197ms/step - loss: 0.0611 - accuracy: 0.9789 - val_loss: 0.0372 - val_accuracy: 0.9880
# Epoch 10/50
# 219/219 [==============================] - 44s 200ms/step - loss: 0.0666 - accuracy: 0.9771 - val_loss: 0.0333 - val_accuracy: 0.9887
# Epoch 11/50
# 219/219 [==============================] - 43s 194ms/step - loss: 0.0345 - accuracy: 0.9891 - val_loss: 0.0221 - val_accuracy: 0.9933
# Epoch 12/50
# 219/219 [==============================] - 45s 205ms/step - loss: 0.0572 - accuracy: 0.9797 - val_loss: 0.0304 - val_accuracy: 0.9893
# Epoch 13/50
# 219/219 [==============================] - 44s 199ms/step - loss: 0.0341 - accuracy: 0.9874 - val_loss: 0.0640 - val_accuracy: 0.9807
# Epoch 14/50
# 219/219 [==============================] - 43s 197ms/step - loss: 0.0366 - accuracy: 0.9867 - val_loss: 0.0869 - val_accuracy: 0.9700
# Epoch 15/50
# 219/219 [==============================] - 44s 201ms/step - loss: 0.0576 - accuracy: 0.9834 - val_loss: 0.0938 - val_accuracy: 0.9600
# Epoch 16/50
# 219/219 [==============================] - 44s 199ms/step - loss: 0.0299 - accuracy: 0.9901 - val_loss: 0.0564 - val_accuracy: 0.9833
# Epoch 17/50
# 219/219 [==============================] - 43s 197ms/step - loss: 116.7690 - accuracy: 0.8969 - val_loss: 91.2856 - val_accuracy: 0.4684
# Epoch 18/50
# 219/219 [==============================] - 42s 193ms/step - loss: 986.2834 - accuracy: 0.5143 - val_loss: 0.8046 - val_accuracy: 0.6083
# Epoch 19/50
# 219/219 [==============================] - 43s 197ms/step - loss: 0.7382 - accuracy: 0.6269 - val_loss: 0.6904 - val_accuracy: 0.6103
# Epoch 20/50
# 219/219 [==============================] - 43s 196ms/step - loss: 0.6563 - accuracy: 0.6527 - val_loss: 1.0650 - val_accuracy: 0.5490
# Epoch 21/50
# 219/219 [==============================] - 44s 198ms/step - loss: 0.6622 - accuracy: 0.6563 - val_loss: 0.5465 - val_accuracy: 0.7015
# Epoch 22/50
# 219/219 [==============================] - 43s 195ms/step - loss: 0.5169 - accuracy: 0.7763 - val_loss: 1.0161 - val_accuracy: 0.6282
# Epoch 23/50
# 219/219 [==============================] - 43s 198ms/step - loss: 0.4051 - accuracy: 0.8336 - val_loss: 0.3410 - val_accuracy: 0.8541
# Epoch 24/50
# 219/219 [==============================] - 42s 192ms/step - loss: 0.4418 - accuracy: 0.8306 - val_loss: 0.3187 - val_accuracy: 0.8741
# Epoch 25/50
# 219/219 [==============================] - 45s 207ms/step - loss: 0.5045 - accuracy: 0.8210 - val_loss: 0.3096 - val_accuracy: 0.8807
# Epoch 26/50
# 219/219 [==============================] - 46s 210ms/step - loss: 0.4077 - accuracy: 0.8493 - val_loss: 0.8508 - val_accuracy: 0.7275
# Epoch 27/50
# 219/219 [==============================] - 45s 205ms/step - loss: 0.3853 - accuracy: 0.8613 - val_loss: 0.2822 - val_accuracy: 0.8814
# Epoch 28/50
# 219/219 [==============================] - 45s 203ms/step - loss: 0.3052 - accuracy: 0.8834 - val_loss: 0.2702 - val_accuracy: 0.8987
# Epoch 29/50
# 219/219 [==============================] - 44s 202ms/step - loss: 0.3343 - accuracy: 0.8787 - val_loss: 0.2803 - val_accuracy: 0.8887
# Epoch 30/50
# 219/219 [==============================] - 45s 206ms/step - loss: 0.6717 - accuracy: 0.8377 - val_loss: 1.1929 - val_accuracy: 0.6709
# Epoch 31/50
# 219/219 [==============================] - 44s 202ms/step - loss: 0.5020 - accuracy: 0.8639 - val_loss: 0.3018 - val_accuracy: 0.8794
# Epoch 32/50
# 219/219 [==============================] - 46s 209ms/step - loss: 0.2754 - accuracy: 0.8939 - val_loss: 0.2421 - val_accuracy: 0.9061
# Epoch 33/50
# 219/219 [==============================] - 44s 202ms/step - loss: 0.2449 - accuracy: 0.9081 - val_loss: 0.2151 - val_accuracy: 0.9127
# Epoch 34/50
# 219/219 [==============================] - 46s 212ms/step - loss: 0.2408 - accuracy: 0.9070 - val_loss: 0.2011 - val_accuracy: 0.9207
# Epoch 35/50
# 219/219 [==============================] - 46s 211ms/step - loss: 0.2827 - accuracy: 0.8986 - val_loss: 0.3489 - val_accuracy: 0.8921
# Epoch 36/50
# 219/219 [==============================] - 46s 209ms/step - loss: 0.2436 - accuracy: 0.9061 - val_loss: 0.1858 - val_accuracy: 0.9274
# Epoch 37/50
# 219/219 [==============================] - 46s 209ms/step - loss: 0.3922 - accuracy: 0.8816 - val_loss: 0.2206 - val_accuracy: 0.9147
# Epoch 38/50
# 219/219 [==============================] - 46s 209ms/step - loss: 0.3930 - accuracy: 0.8926 - val_loss: 0.2497 - val_accuracy: 0.9014
# Epoch 39/50
# 219/219 [==============================] - 45s 204ms/step - loss: 0.2568 - accuracy: 0.9023 - val_loss: 0.2353 - val_accuracy: 0.9014
# Epoch 40/50
# 219/219 [==============================] - 46s 211ms/step - loss: 0.2128 - accuracy: 0.9203 - val_loss: 0.1972 - val_accuracy: 0.9194
# Epoch 41/50
# 219/219 [==============================] - 47s 214ms/step - loss: 0.1932 - accuracy: 0.9271 - val_loss: 0.1686 - val_accuracy: 0.9314
# Epoch 42/50
# 219/219 [==============================] - 45s 206ms/step - loss: 0.9364 - accuracy: 0.8577 - val_loss: 0.4958 - val_accuracy: 0.8414
# Epoch 43/50
# 219/219 [==============================] - 44s 202ms/step - loss: 0.2685 - accuracy: 0.9004 - val_loss: 0.2691 - val_accuracy: 0.9054
# Epoch 44/50
# 219/219 [==============================] - 44s 202ms/step - loss: 0.2500 - accuracy: 0.9061 - val_loss: 0.1935 - val_accuracy: 0.9201
# Epoch 45/50
# 219/219 [==============================] - 47s 215ms/step - loss: 0.2170 - accuracy: 0.9183 - val_loss: 0.1944 - val_accuracy: 0.9214
# Epoch 46/50
# 219/219 [==============================] - 45s 207ms/step - loss: 0.2033 - accuracy: 0.9190 - val_loss: 0.2094 - val_accuracy: 0.9161
# Epoch 47/50
# 219/219 [==============================] - 46s 208ms/step - loss: 0.2298 - accuracy: 0.9140 - val_loss: 0.2110 - val_accuracy: 0.9147
# Epoch 48/50
# 219/219 [==============================] - 46s 211ms/step - loss: 0.1968 - accuracy: 0.9251 - val_loss: 0.1742 - val_accuracy: 0.9287
# Epoch 49/50
# 219/219 [==============================] - 46s 209ms/step - loss: 0.2066 - accuracy: 0.9214 - val_loss: 0.1787 - val_accuracy: 0.9267
# Epoch 50/50
# 219/219 [==============================] - 46s 212ms/step - loss: 0.1832 - accuracy: 0.9307 - val_loss: 0.1519 - val_accuracy: 0.9420

# %%
# plotting the loss
plt.plot(history.history['loss'],label = 'Training loss')
plt.plot(history.history['val_loss'], label = 'Validation loss')
#plt.title('loss')
plt.legend()
plt.show()

# %%
# Both Validation and Training accuracy is shown here

plt.plot(history.history['accuracy'], label='Training accuracy')
plt.plot(history.history['val_accuracy'], label='Validation accuracy')
#plt.title('Accuracy')
plt.legend()
plt.show()

# %%
# CHECKING THE CONFUSION MATRIX

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
Y_pred = model.predict(test_set)
y_pred = np.argmax(Y_pred ,axis =1)
# Out:
# 1499/1499 [==============================] - 155s 103ms/step

# %%
print('Classification Report')
target_names = ['aca','n']
print(classification_report(test_set.classes, y_pred, target_names=target_names))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#          aca       0.94      0.96      0.95       770
#            n       0.96      0.94      0.95       729
#
#     accuracy                           0.95      1499
#    macro avg       0.95      0.95      0.95      1499
# weighted avg       0.95      0.95      0.95      1499

# %%
loss, acc = model.evaluate_generator(test_set, len(test_set))

print ("\n\n================================\n\n")
print ("Loss: {}".format(loss))
print ("Accuracy: {0:.2f} %".format(acc * 100))
print ("\n\n================================\n\n")

test_set.reset()
# Out:
# <ipython-input-24-9a3d6d22a8aa>:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   loss, acc = model.evaluate_generator(test_set, len(test_set))
# ================================
#
#
# Loss: 0.16013963520526886
# Accuracy: 94.86 %
#
#
# ================================

# %%
result = model.evaluate(test_set,batch_size=128)
print("test_loss, test accuracy",result)
# Out:
# 1499/1499 [==============================] - 10s 7ms/step - loss: 0.1601 - accuracy: 0.9486
# test_loss, test accuracy [0.16013963520526886, 0.9486324191093445]

# %%
preds = model.predict(test_set,verbose=1)
predictions = preds.copy()
predictions[predictions <= 0.5] = 0
predictions[predictions > 0.5] = 1

# %%
#Confusion Matrix and Classification Report
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

#Y_pred = model.predict_generator(validation_generator, nb_validation_samples //
#batch_size+1)
y_pred = np.argmax(preds, axis=1)

print('Confusion Matrix')
print(confusion_matrix(test_set.classes, y_pred))
# Out:
# Confusion Matrix
# [[738  32]
#  [ 45 684]]

# %%
print('Classification Report')
target_names = [ 'Colon Benign','Colon Adenocarcinoma']
print(classification_report(test_set.classes, y_pred, target_names=target_names))
# Out:
# Classification Report
#                       precision    recall  f1-score   support
#
#         Colon Benign       0.94      0.96      0.95       770
# Colon Adenocarcinoma       0.96      0.94      0.95       729
#
#             accuracy                           0.95      1499
#            macro avg       0.95      0.95      0.95      1499
#         weighted avg       0.95      0.95      0.95      1499

# %%
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import f1_score

precision_score(test_set.classes, y_pred) , recall_score(test_set.classes, y_pred) ,  f1_score(test_set.classes, y_pred)
# Out:
# (0.9553072625698324, 0.9382716049382716, 0.946712802768166)

# %%
import sklearn.metrics as metrics
fpr, tpr, threshold = metrics.roc_curve(test_set.classes, y_pred)
roc_auc = metrics.auc(fpr, tpr)
import matplotlib.pyplot as plt
#plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'k--')
# plt.xlim([0, 1])
# plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
#plt.title('ROC curve')

plt.show()

# %%
from sklearn.metrics import classification_report,confusion_matrix
cm = pd.DataFrame(data=confusion_matrix( y_true= test_set.classes, y_pred= y_pred, labels=[0, 1]), index=["Actual Normal", "Actul Adenocarcinoma"],columns=["Predicted Benign", "Predicted Adenocarcinoma"])
import seaborn as sns
sns.heatmap(cm,annot=True,fmt="d",cmap="BuPu")
